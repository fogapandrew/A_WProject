# %%
from MyApp.extraction import *

# %%
book = GetRandomBook()

title, book_created_date, book_publisher ,book_isbn , image = book.get_random_book()

# %%
print(f"Title: {title}")
print(f"Created At: {book_created_date}")
print(f"Publisher: {book_publisher}")
print(f"ISBN: {book_isbn}")
image
# Out:
# Title: The Shining
# Created At: 2023-11-13T23:48:48.219Z
# Publisher: Doubleday
# ISBN: 978-0-385-12167-5
# <PIL.Image.Image image mode=RGB size=200x300>
